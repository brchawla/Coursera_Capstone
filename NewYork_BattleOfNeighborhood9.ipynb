# %% [markdown]
# <H1>Neighborhoods in NewYork, NY</H1>

# %% [markdown]
# <H2>Capstone Project Week4</H2>

# %% [markdown]
# <H3>Introduction</H3>
# NewYork is a busy city with multicultural presence from all over the world
# It is also one of the biggest metropolitan city with lots of infrastructure already built in and improvement opportunities
# City keeps growing as well with more andmore development, hence it provides constant opportunity to tackle any data mining related problem.
# The focus of this session will be along the following items:
#
# 1. Neighborhoods with crime rates
# 2. Population density with the crime neighborhood areas
# 3. Busy venues
# 4. Need for a restaurant in a specific area

# %%
from PIL import Image
import requests
url = 'https://www.nycgovparks.org/common_images/events/full/559440414964f.jpg'
nyIm = Image.open(requests.get(url, stream=True).raw)
nyIm
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x7F46D0464438>

# %% [markdown]
# <H3>Data</H3>
# Following data sources will be utilized to address and understand the problems mentioned in the Introduction section
#
# 1. https://cocl.us/new_york_dataset --> this dataset will provide the neighborhood with borough information with lattitude and longitude to
# map the area we will be workinng with
#
# 2. https://opendata.cityofnewyork.us/ --> there are several datasets at this repository and we will be utilizing a few to address the
# problem and study the points mentioned in the Introduction section above
